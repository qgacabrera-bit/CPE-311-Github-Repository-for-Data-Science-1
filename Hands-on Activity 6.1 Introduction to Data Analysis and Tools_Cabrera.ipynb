# %% [markdown]
# <h2>Hands-on Activity 6.1 Introduction to Data Analysis and Tools</h2>

# %% [markdown]
# CPE311 Computational Thinking with Python
#
# Name: Cabrera, Gabriel A.
#
# Section: CPE22S3
#
# Performed on: 02/12/2026
#
# Submitted on: 02/12/2026
#
# Submitted to: Engr. Neal Barton James Matira

# %% [markdown]
# <h3>6.1 Intended Learning Outcome</h3>
#
# 1. Use pandas and numpy data analysis tools.
#
# 2. Demonstrate how to analyze data using numpy and pandas

# %% [markdown]
# <h3>6.2 Resources:</h3>
#
# - Personal Computer
# - Jupyter Notebook
# - Internet Connection

# %% [markdown]
# <h3>6.3 Supplementary Activities:</h3>
#
# <h4>Exercise 1</h4>
# Run the given code below for exercises 1 and 2, perform the given tasks without using any Python modules.

# %%
import random
random.seed(0)
salaries = [round(random.random()*1000000, -3) for _ in range(100)]

# %% [markdown]
# Using the data generated above, calculate the following statistics without importing anything from the statistics module in the
# standard library (https://docs.python.org/3/library/statistics.html) and then confirm your results match up to those that are
# obtained when using the statistics module (where possible):
#
# Mean
#
# Median
#
# Mode (hint: check out the Counter in the collections module of the standard library at
# https://docs.python.org/3/library/collections.html#collections.Counter)
#
# Sample variance
#
# Sample standard deviation

# %%
##No import
mean_no = sum(salaries) / len(salaries) #Average off all the salaries from generated data
print(f"Mean Salary: {mean_no:.2f}")
median_no = sorted(salaries)[len(salaries) // 2] # Middle value after sorting
print(f"Median Salary: {median_no:.2f}")
mode_no = max(set(salaries), key=salaries.count) # Most frequent value
print(f"Mode Salary: {mode_no:.2f}")
variance_no = sum((x - mean_no) ** 2 for x in salaries) / (len(salaries)-1) #How spread out the salaries are
print(f"Variance of Salary: {variance_no:.2f}")
std_dev_no = variance_no ** 0.5 # Square root of variance
print(f"Standard Deviation of Salary: {std_dev_no:.2f}")
# Out:
# Mean Salary: 585690.00
# Median Salary: 590000.00
# Mode Salary: 477000.00
# Variance of Salary: 70664054444.44
# Standard Deviation of Salary: 265827.11

# %%
#With statistics library
from statistics import mean, median, mode, variance, stdev
mean_stat = mean(salaries)
median_stat = median(salaries)
mode_stat = mode(salaries)
variance_stat = variance(salaries)
stdev_stat = stdev(salaries)
print(f"Mean: {mean_stat:.2f}")
print(f"Median: {median_stat:.2f}")
print(f"Mode: {mode_stat:.2f}")
print(f"Variance: {variance_stat:.2f}")
print(f"Standard Deviation: {stdev_stat:.2f}")
# Out:
# Mean: 585690.00
# Median: 589000.00
# Mode: 477000.00
# Variance: 70664054444.44
# Standard Deviation: 265827.11

# %% [markdown]
# Since they both use the same formula, the results are the same, using the library is just easier since we would not have to code the formula manually.

# %% [markdown]
# <h4>Exercise 2</h4>
# Using the same data, calculate the following statistics using the functions in the statistics module where appropriate:
#
# - Range
# - Coefficient of variation
# - Interquartile range
# - Quartile coefficient of dispersion

# %%
range_stat = max(salaries) - min(salaries) # Difference between highest and lowest salary
print(f"Range of Salary: {range_stat:.2f}") 
coef_var = (std_dev_no / mean_stat) * 100 # Standard deviation divided by mean, in percent
print(f"Coefficient of Variation: {coef_var:.2f}%")
int_range = sorted(salaries)[int(0.75*len(salaries))] - sorted(salaries)[int(0.25*len(salaries))] # Difference between 75th and 25th percentiles
print(f"Interquartile Range: {int_range:.2f}")
coef_disp = (int_range / mean_stat) * 100 # Interquartile range divided by mean, in percent
print(f"Coefficient of Dispersion: {coef_disp:.2f}%")
# Out:
# Range of Salary: 995000.00
# Coefficient of Variation: 45.39%
# Interquartile Range: 420000.00
# Coefficient of Dispersion: 71.71%

# %% [markdown]
# <h4>Exercise 3: Pandas for Data Analysis</h4>
# Load the diabetes.csv file. Convert the diabetes.csv into dataframe
# Perform the following tasks in the diabetes dataframe:
#
# 1. Identify the column names
# 2. Identify the data types of the data
# 3. Display the total number of records
# 4. Display the first 20 records
# 5. Display the last 20 records
# 6. Change the Outcome column to Diagnosis
# 7. Create a new column Classification that display "Diabetes" if the value of outcome is 1 , otherwise "No Diabetes"
# 8. Create a new dataframe "withDiabetes" that gathers data with diabetes
# 9. Create a new dataframe "noDiabetes" thats gathers data with no diabetes
# 10. Create a new dataframe "Pedia" that gathers data with age 0 to 19
# 11. Create a new dataframe "Adult" that gathers data with age greater than 19
# 12. Use numpy to get the average age and glucose value.
# 13. Use numpy to get the median age and glucose value.
# 14. Use numpy to get the middle values of glucose and age.
# 15. Use numpy to get the standard deviation of the skinthickness.

# %%
import numpy as np
import pandas as pd

# %%
print("1. Identify the column names")
df = pd.read_csv('diabetes.csv')
print(df.columns)
print("\n2. Identify the data types of the data")
print(df.dtypes)
print("\n3. Display the total number of records")
print("Total records:", len(df))
print("\n4. Display the first 20 records")
print(df.head(20))
# Out:
# 1. Identify the column names
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')
#
# 2. Identify the data types of the data
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object
#
# 3. Display the total number of records
# Total records: 768
#
# 4. Display the first 20 records
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# ...

# %%
print("\n5. Display the last 20 records")
print(df.tail(20))
print("\n6. Change the Outcome column to Diagnosis")
df.rename(columns={'Outcome': 'Diagnosis'}, inplace=True)
print(df.columns)
print("\n7. Create a new column Classification that display 'Diabetes' if the value of outcome is 1 , otherwise 'No Diabetes'")
df['Classification'] = df['Diagnosis'].apply(lambda x: 'Diabetes' if x == 1 else 'No Diabetes')
print(df[['Diagnosis', 'Classification']])
print("\n8. Create a new dataframe 'withDiabetes' that gathers data with diabetes")
withDiabetes = df[df['Diagnosis'] == 1]
print(withDiabetes)
# Out:
# 5. Display the last 20 records
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# ...

# %%
print("\n9. Create a new dataframe 'noDiabetes' that gathers data with no diabetes")
noDiabetes = df[df['Diagnosis'] == 0]
print(noDiabetes)
print("\n10. Create a new dataframe 'Pedia' that gathers data with age 0 to 19")
Pedia = df[df['Age'] <= 19]
print(Pedia)
print("\n11. Create a new dataframe 'Adult' that gathers data with age greater than 19")
Adult = df[df['Age'] > 19]
print(Adult)
print("\n12. Use numpy to get the average age and glucose value.")
avg_age = np.mean(df['Age'])
avg_glucose = np.mean(df['Glucose'])
print(f"Average Age: {avg_age:.2f}")
print(f"Average Glucose: {avg_glucose:.2f}")
print("\n13. Use numpy to get the median age and glucose value.")
median_age = np.median(df['Age'])
median_glucose = np.median(df['Glucose'])
print(f"Median Age: {median_age:.2f}")
print(f"Median Glucose: {median_glucose:.2f}")
print("\n14. Use numpy to get the middle values of glucose and age.")
middle_age = np.sort(df['Age'])[len(df) // 2]
middle_glucose = np.sort(df['Glucose'])[len(df) // 2]
print(f"Middle Age: {middle_age:.2f}")
print(f"Middle Glucose: {middle_glucose:.2f}")
print("\n15. Use numpy to get the standard deviation of the skinthickness.")
std_skinthickness = np.std(df['SkinThickness'], ddof=1)
print(f"Standard Deviation of SkinThickness: {std_skinthickness:.2f}")
# Out:
# 9. Create a new dataframe 'noDiabetes' that gathers data with no diabetes
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
# ...

# %% [markdown]
# <h3>Conclusion</h3>
# In this activity, I have applied the previous techniques of converting a csv to dataframes, displaying the basic parts like columns, head, and tail, and combining this knowledge with other programming techniques like identifying samples in the data that are part of just one group like the pedia and adults group. This activity also reinforced my skills in statistics, I was able to manually code for the statistics of the randomly generated dataset and I also learned that there are libraries that can make these tasks easier. Using the basic techniques of identifying the groups needed in a data set and also seeing the statistics in them made me realize how fundamental it is to build a foundation in this field and how I can use them in my future projects like in visualizing data and story telling.
