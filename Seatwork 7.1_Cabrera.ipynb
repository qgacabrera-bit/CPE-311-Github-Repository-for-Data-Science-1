# %% [markdown]
# CPE311 Computational Thinking with Python
#
# Name: Cabrera, Gabriel A.
#
# Section: CPE22S3
#
# Performed on: 02/12/2026
#
# Submitted on: 02/12/2026
#
# Submitted to: Engr. Neal Barton James Matira

# %% [markdown]
# Using the meteorite data from the Meteorite_Landings.csv file, update the year column to only contain the year, convert it to a numeric data type, and create a new column indicating whether the meteorite was observed falling before 1970. Set the index to the id column and extract all the rows with IDs between 10,036 and 10,040 (inclusive) with loc[].
#
# Hint 1: Use year.str.slice() to grab a substring.
#
# Hint 2: Make sure to sort the index before using loc[] to select the range.
#
# Bonus: There's a data entry error in the year column. Can you find it? (Don't spend too much time on this.)

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('Meteorite_Landings.csv')

# %%
#Update the year column to only contain the year
df['year'] = df['year'].str.slice(6, 10)
# Convert the year column to a numeric data type
df['year'] = pd.to_numeric(df['year'])
# Create a new column indicating whether the meteorite was observed falling before 1970
df['observed_before_1970'] = df['year'] < 1970
# Set the index to the id column
df.set_index('id', inplace=True)
# Sort the index before using loc[] to select the range
df.sort_index(inplace=True)
# Extract all the rows with IDs between 10,036 and 10,040 (inclusive) with loc[]
result = df.loc[10036:10040]
print(result)
# Out:
#             name nametype         recclass  mass (g)   fall    year    reclat  \
# id
# 10036     Enigma    Valid               H4      94.0  Found  1967.0  31.33333
# 10037       Enon    Valid  Iron, ungrouped     763.0  Found  1883.0  39.86667
# 10038      Enshi    Valid               H5    8000.0   Fell  1974.0  30.30000
# 10039  Ensisheim    Valid              LL6  127000.0   Fell  1491.0  47.86667
#
#          reclong            GeoLocation  observed_before_1970
# id
# 10036  -82.31667  (31.33333, -82.31667)                  True
# 10037  -83.95000     (39.86667, -83.95)                  True
# 10038  109.50000          (30.3, 109.5)                 False
# 10039    7.35000       (47.86667, 7.35)                  True

# %% [markdown]
# Data entry error in the year column includes time, which should be fine but this dataset only has 12 AM as the designated time, we can ignore or remove it since it would not matter for this dataset.
